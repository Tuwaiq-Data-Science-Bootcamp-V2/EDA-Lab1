# %% [markdown]
# ### Choose a dataset to Visulaize
# * Import needed libraries
# * Load your dataset

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("HRDataset_v14.csv")
df.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df['MarriedID'].value_counts()
# Out:
# 0    187
# 1    124
# Name: MarriedID, dtype: int64

# %%
df.dtypes
# Out:
# Employee_Name                  object
# EmpID                           int64
# MarriedID                       int64
# MaritalStatusID                 int64
# GenderID                        int64
# EmpStatusID                     int64
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID          int64
# Salary                          int64
# Termd                           int64
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# DateofTermination              object
# TermReason                     object
# EmploymentStatus               object
# ...

# %%
import datetime
from datetime import date,datetime
from dateutil.relativedelta import relativedelta

# %%
w=date.today()
w=w.strftime("%Y-%m-%d")

# %%
def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs(relativedelta(d2, d1).years)

# %%
d=pd.to_datetime(df["DOB"]).apply(lambda x:x.strftime("%Y-%m-%d"))
df["Age"]=d.apply(lambda x:days_between(x, w))
df["Age"]
# Out:
# 0      39
# 1      47
# 2      34
# 3      34
# 4      33
#        ..
# 306    37
# 307    40
# 308    43
# 309    43
# 310    44
# Name: Age, Length: 311, dtype: int64

# %%
plt.figure(figsize=(8,6))
sns.set_theme(style="darkgrid")
plt.grid(True)
ax=sns.kdeplot(df["Age"],shade=True,color="red")
ax.grid(which='major', axis='x', zorder=0, color='#DFFF00', linewidth=0.4)
ax.grid(which='major', axis='y', zorder=0, color='#DFFF00', linewidth=0.4)
plt.rc('font', size=10,weight="bold")
plt.xticks(rotation=20)
plt.tight_layout()

# %% [markdown]
# We note that the majority of employees are from the age of 32 to 48, i.e. the youth category

# %% [markdown]
# **Salary distribution based on Gender**

# %%
plt.figure(figsize=(8,6))
sns.set_theme(style="darkgrid")
sns.kdeplot(df.loc[(df["Sex"]=="F"),"Salary"],shade=True,color="red",label="Female",alpha=0.1)
sns.kdeplot(df.loc[(df["Sex"]=="M "),"Salary"],shade=True,color="yellow",label="Male",alpha=0.1) #shade=True
plt.legend()

# %% [markdown]
# We note that the density of female employees is more than that of men, at a salary of 50,000 to 90,000.

# %%
h=pd.DataFrame(df.groupby(["Sex","PerformanceScore"])["EmpID"].count()).reset_index()
h
# Out:
#   Sex   PerformanceScore  EmpID
# 0   F            Exceeds     20
# 1   F        Fully Meets    142
# 2   F  Needs Improvement      9
# 3   F                PIP      5
# 4  M             Exceeds     17
# 5  M         Fully Meets    101
# 6  M   Needs Improvement      9
# 7  M                 PIP      8

# %%
fig=px.bar(h, x='PerformanceScore', y='EmpID', color='Sex', title='Performance Score Gender-Wise',
      labels={'PerformanceScore': 'Performance Score', 'EmpID': 'Count of Employees'},
      barmode="group")
# Set fontsize and uniformtext_mode='hide' says to hide the text if it won't fit
fig.update_layout(uniformtext_minsize=10)
fig
# Out:
# <div>                            <div id="d2878dcb-e0bd-44ff-9fb5-44a67be22da0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d2878dcb-e0bd-44ff-9fb5-44a67be22da0")) {                    Plotly.newPlot(                        "d2878dcb-e0bd-44ff-9fb5-44a67be22da0",                        [{"alignmentgroup":"True","hovertemplate":"Sex=F<br>Performance Score=%{x}<br>Count of Employees=%{y}<extra></extra>","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["Exceeds","Fully Meets","Needs Improvement","PIP"],"xaxis":"x","y":[20,142,9,5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sex=M <br>Performance Score=%{x}<br>Coun
# ...

# %% [markdown]
# We note that Women are more efficient compared to Men.

# %%
v=df[["EmpID","DateofHire","DateofTermination","TermReason"]].copy()
v.dropna(inplace=True) #Removing those employees who are still working in the company
v.head()
# Out:
#     EmpID DateofHire DateofTermination        TermReason
# 1   10084  3/30/2015         6/16/2016     career change
# 2   10196   7/5/2011         9/24/2012             hours
# 4   10069  7/11/2011          9/6/2016  return to school
# 10  10252  1/10/2011         1/12/2017  Another position
# 11  10242   4/2/2012         9/19/2016           unhappy

# %%
v.shape  #Looks like 311-104=207 employees have been retained by the company
# Out:
# (104, 4)

# %%
v.TermReason.nunique(),v.TermReason.unique() #One of the employees' was a Gangster lol.
# Out:
# (17,
#  array(['career change', 'hours', 'return to school', 'Another position',
#         'unhappy', 'attendance', 'performance',
#         'Learned that he is a gangster', 'retiring',
#         'relocation out of area', 'more money', 'military',
#         'no-call, no-show', 'Fatal attraction',
#         'maternity leave - did not return', 'medical issues',
#         'gross misconduct'], dtype=object))

# %%
v1=pd.DataFrame(v.groupby("TermReason")["EmpID"].count()).reset_index()
v1
# Out:
#                           TermReason  EmpID
# 0                   Another position     20
# 1                   Fatal attraction      1
# 2      Learned that he is a gangster      1
# 3                         attendance      7
# 4                      career change      9
# 5                   gross misconduct      1
# 6                              hours      8
# 7   maternity leave - did not return      3
# 8                     medical issues      3
# 9                           military      4
# 10                        more money     11
# 11                  no-call, no-show      4
# 12                       performance      4
# 13            relocation out of area      5
# 14                          retiring      4
# 15                  return to school      5
# 16                           unhappy     14

# %%
plt.figure(figsize=(20,12))
sns.scatterplot(data=v1.sort_values(by=["EmpID"]), x="TermReason", y="EmpID", size="EmpID",color="blue", legend=False, sizes=(2000, 10000), alpha=0.8, linewidth=6)
plt.xlabel("Various Reasons",size=20)
plt.ylabel("Number of Employees",size=20)
plt.title("To determine why the majority of employees are leaving the company", loc="center")
plt.yticks(fontsize=20) 
plt.xticks(fontsize=15,rotation=90) 
# show the graph
plt.tight_layout()

# %% [markdown]
# **The top three reasons for the Employees to leave the company were:**
#
# 1-A better position in another company.
#
# 2-Lack of Job Satisfaction(unhappiness)
#
# 3-A better salary offered by rival companies.

# %% [markdown]
# ### Bivariate Visualization
# * Plot two Charts
# * Provide each charts with at least two insights

# %%
df3= df[['Salary', 'Absences']]
df3

plt.scatter(x='Salary',y='Absences' , data=df3)
plt.xlabel("Salary")
plt.ylabel("Absences")
plt.title('Salary Vs. Number of Absences')
plt.show()

# %% [markdown]
# We note that the number of days of absence does not affect the employees' salaries

# %% [markdown]
# ### Univariate Visualization
# * Plot two Charts
# * Provide each charts with at least two insights

# %%
plt.figure(figsize=(15,15))
sort = df.groupby('Position').size().sort_values().index[::-1]
sns.countplot(data=df, y = 'Position', color = 'blue', order=sort)
plt.yticks(fontsize=15) 
plt.xticks(fontsize=15) 
# show the graph
plt.tight_layout()

# %% [markdown]
# 1-We can see job vacancies easily.
#
# 2-The employees of the sales and production department are the most represented in the data

# %% [markdown]
# **Salary disrtribution**

# %%
plt.figure(figsize=(10,10));
sns.displot(df, x="Salary", bins=20);

# %% [markdown]
# Most of the employees have salaries between 5,000 to 10,000, and the highest is 6,000
